# %%
import pandas as pd

#doi_csv = pd.read_csv(r)
#dois = list(doi_csv["RetractionDOI"])
dois = ['10.1103/PhysRevD.94.112005']
from pyalex import Works, config

# Set your email to join the polite pool
config.email = "parsazahedizzz@gmail.com"


# Function to retrieve article information based on DOIs
def get_article_info(dois):
    articles = []
    for doi in dois:
        try:
            work = Works()[f"https://doi.org/{doi}"]
            articles.append(work)
        except Exception as e:
            print(f"Error retrieving DOI {doi}: {e}")
    return articles


# Retrieve article information
article_info = get_article_info(dois)

# %%
article_info
# Out:
# [{'id': 'https://openalex.org/W2519174018',
#   'doi': 'https://doi.org/10.1103/physrevd.94.112005',
#   'title': 'Studies of inclusive four-jet production with two <mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="inline"><mml:mi>b</mml:mi></mml:math> -tagged jets in proton-proton collisions at 7 TeV',
#   'display_name': 'Studies of inclusive four-jet production with two <mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="inline"><mml:mi>b</mml:mi></mml:math> -tagged jets in proton-proton collisions at 7 TeV',
#   'publication_year': 2016,
#   'publication_date': '2016-12-08',
#   'ids': {'openalex': 'https://openalex.org/W2519174018',
#    'doi': 'https://doi.org/10.1103/physrevd.94.112005',
#    'mag': '2519174018'},
#   'language': 'en',
#   'primary_location': {'is_oa': True,
#    'landing_page_url': 'https://doi.org/10.1103/physrevd.94.112005',
#    'pdf_url': 'http://link.aps.org/pdf/10.1103/PhysRevD.94.112005',
#    'source': {'id': 'https://openalex.org/S4210238307',
#     'display_name': 'Physical review. D/Physical review. D.',
#     'issn_l': '2470-0010',
#     'issn': ['2470-0010', '2470-0029', '2470-0037'],
#     'is_oa': False,
#     'is_in_doaj': False,
#     'is_indexed_in_scopus': True,
#     'is_core': True,
#     'host_organization': 'https://openalex.org/P4310320261',
#     'host_organization_name': 'American Physical Society',
#     'host_organization_lineage': ['https://openalex.org/P4310320261'],
#     'host_organization_lineage_names': ['American Physical Society'],
#     'type': 'journal'},
#    'license': 'cc-by',
#    'license_id': 'https://openalex.org/licenses/cc-by',
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   'type': 'article',
#   'type_crossref': 'journal-article',
#   'indexed_in': ['arxiv', 'crossref', 'datacite'],
#   'open_access': {'is_oa': True,
#    'oa_status': 'hybrid',
#    'oa_url': 'http://link.aps.org/pdf/10.1103/PhysRevD.94.112005',
#    'any_repository_has_fulltext': True},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A5005250779',
#      'display_name': 'V. Khachatryan',
#      'orcid': 'https://orcid.org/0000-0003-2567-2930'},
#     'institutions': [{'id': 'https://openalex.org/I132091411',
#       'display_name': 'A. Alikhanyan National Laboratory',
#       'ror': 'https://ror.org/00ad27c73',
#       'country_code': 'AM',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I132091411']}],
#     'countries': ['AM'],
#     'is_corresponding': False,
#     'raw_author_name': 'V. Khachatryan',
#     'raw_affiliation_strings': ['Yerevan Physics Institute, Yerevan, Armenia'],
#     'affiliations': [{'raw_affiliation_string': 'Yerevan Physics Institute, Yerevan, Armenia',
#       'institution_ids': ['https://openalex.org/I132091411']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107826728',
#      'display_name': 'A. M. Sirunyan',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I132091411',
#       'display_name': 'A. Alikhanyan National Laboratory',
#       'ror': 'https://ror.org/00ad27c73',
#       'country_code': 'AM',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I132091411']}],
#     'countries': ['AM'],
#     'is_corresponding': False,
#     'raw_author_name': 'A.\u2009M. Sirunyan',
#     'raw_affiliation_strings': ['Yerevan Physics Institute, Yerevan, Armenia'],
#     'affiliations': [{'raw_affiliation_string': 'Yerevan Physics Institute, Yerevan, Armenia',
#       'institution_ids': ['https://openalex.org/I132091411']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5069509278',
#      'display_name': 'A. Tumasyan',
#      'orcid': 'https://orcid.org/0009-0000-0684-6742'},
#     'institutions': [{'id': 'https://openalex.org/I132091411',
#       'display_name': 'A. Alikhanyan National Laboratory',
#       'ror': 'https://ror.org/00ad27c73',
#       'country_code': 'AM',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I132091411']}],
#     'countries': ['AM'],
#     'is_corresponding': False,
#     'raw_author_name': 'A. Tumasyan',
#     'raw_affiliation_strings': ['Yerevan Physics Institute, Yerevan, Armenia'],
#     'affiliations': [{'raw_affiliation_string': 'Yerevan Physics Institute, Yerevan, Armenia',
#       'institution_ids': ['https://openalex.org/I132091411']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5074924703',
#      'display_name': 'W. Adam',
#      'orcid': 'https://orcid.org/0000-0001-9099-4341'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'W. Adam',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5007914806',
#      'display_name': 'E. Asilar',
#      'orcid': 'https://orcid.org/0000-0001-5680-599X'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'E. Asilar',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5114334441',
#      'display_name': 'T. Bergauer',
#      'orcid': 'https://orcid.org/0000-0002-5786-0293'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'T. Bergauer',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107411550',
#      'display_name': 'J. Brandstetter',
#      'orcid': 'https://orcid.org/0000-0003-3881-976X'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'J. Brandstetter',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107868855',
#      'display_name': 'E. Brondolin',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'E. Brondolin',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5086528441',
#      'display_name': 'M. Dragicevic',
#      'orcid': 'https://orcid.org/0000-0003-1967-6783'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'M. Dragicevic',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5113501345',
#      'display_name': 'J. Erö',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'J. Erö',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5077262177',
#      'display_name': 'M. Flechl',
#      'orcid': 'https://orcid.org/0000-0003-4750-3548'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'M. Flechl',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5102904489',
#      'display_name': 'M. Friedl',
#      'orcid': 'https://orcid.org/0000-0002-7420-2559'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'M. Friedl',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5027832388',
#      'display_name': 'R. Frühwirth',
#      'orcid': 'https://orcid.org/0000-0002-0054-3369'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'R. Frühwirth',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5054462267',
#      'display_name': 'V. M. Ghete',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'V.\u2009M. Ghete',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5106295240',
#      'display_name': 'C. Hartl',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'C. Hartl',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5112601085',
#      'display_name': 'N. Hörmann',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'N. Hörmann',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5112409794',
#      'display_name': 'J. Hrubec',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'J. Hrubec',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5078050797',
#      'display_name': 'M. Jeitler',
#      'orcid': 'https://orcid.org/0000-0002-5141-9560'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'M. Jeitler',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5020730993',
#      'display_name': 'A. C. König',
#      'orcid': 'https://orcid.org/0000-0001-6702-6473'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'A. König',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5083183920',
#      'display_name': 'I. Krätschmer',
#      'orcid': 'https://orcid.org/0000-0002-5636-9259'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'I. Krätschmer',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5010908602',
#      'display_name': 'D. Liko',
#      'orcid': 'https://orcid.org/0000-0002-3380-473X'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'D. Liko',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107825086',
#      'display_name': 'T. Matsushita',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'T. Matsushita',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5057586634',
#      'display_name': 'I. Mikulec',
#      'orcid': 'https://orcid.org/0000-0003-0385-2746'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'I. Mikulec',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107830750',
#      'display_name': 'D. Rabady',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'D. Rabady',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5084722176',
#      'display_name': 'N. Rad',
#      'orcid': 'https://orcid.org/0000-0002-5204-0851'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'N. Rad',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5110737549',
#      'display_name': 'B. Rahbaran',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'B. Rahbaran',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5109902673',
#      'display_name': 'H. Rohringer',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'H. Rohringer',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5087831201',
#      'display_name': 'J. Schieck',
#      'orcid': 'https://orcid.org/0000-0002-1058-8093'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'J. Schieck',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107829101',
#      'display_name': 'J. Strauss',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'J. Strauss',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5110252917',
#      'display_name': 'W. Treberer-Treberspurg',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'W. Treberer-Treberspurg',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5009221549',
#      'display_name': 'W. Waltenberger',
#      'orcid': 'https://orcid.org/0000-0002-6215-7228'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'W. Waltenberger',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5108167515',
#      'display_name': 'C.-E. Wulz',
#      'orcid': 'https://orcid.org/0000-0001-9226-5812'},
#     'institutions': [{'id': 'https://openalex.org/I4210129701',
#       'display_name': 'Institute of High Energy Physics',
#       'ror': 'https://ror.org/039shy520',
#       'country_code': 'AT',
#       'type': 'facility',
#       'lineage': ['https://openalex.org/I138211613',
#        'https://openalex.org/I4210129701']}],
#     'countries': ['AT'],
#     'is_corresponding': False,
#     'raw_author_name': 'C.-E. Wulz',
#     'raw_affiliation_strings': ['Institut für Hochenergiephysik der OeAW, Wien, Austria'],
#     'affiliations': [{'raw_affiliation_string': 'Institut für Hochenergiephysik der OeAW, Wien, Austria',
#       'institution_ids': ['https://openalex.org/I4210129701']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5106306232',
#      'display_name': 'V. Mossolov',
#      'orcid': None},
#     'institutions': [],
#     'countries': ['BY'],
#     'is_corresponding': False,
#     'raw_author_name': 'V. Mossolov',
#     'raw_affiliation_strings': ['National Centre for Particle and High Energy Physics, Minsk, Belarus'],
#     'affiliations': [{'raw_affiliation_string': 'National Centre for Particle and High Energy Physics, Minsk, Belarus',
#       'institution_ids': []}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107839659',
#      'display_name': 'N. Shumeiko',
#      'orcid': None},
#     'institutions': [],
#     'countries': ['BY'],
#     'is_corresponding': False,
#     'raw_author_name': 'N. Shumeiko',
#     'raw_affiliation_strings': ['National Centre for Particle and High Energy Physics, Minsk, Belarus'],
#     'affiliations': [{'raw_affiliation_string': 'National Centre for Particle and High Energy Physics, Minsk, Belarus',
#       'institution_ids': []}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107843080',
#      'display_name': 'J. Suarez Gonzalez',
#      'orcid': None},
#     'institutions': [],
#     'countries': ['BY'],
#     'is_corresponding': False,
#     'raw_author_name': 'J. Suarez Gonzalez',
#     'raw_affiliation_strings': ['National Centre for Particle and High Energy Physics, Minsk, Belarus'],
#     'affiliations': [{'raw_affiliation_string': 'National Centre for Particle and High Energy Physics, Minsk, Belarus',
#       'institution_ids': []}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5011128192',
#      'display_name': 'S. Alderweireldt',
#      'orcid': 'https://orcid.org/0000-0002-8224-7036'},
#     'institutions': [{'id': 'https://openalex.org/I149213910',
#       'display_name': 'University of Antwerp',
#       'ror': 'https://ror.org/008x57b05',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I149213910']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'S. Alderweireldt',
#     'raw_affiliation_strings': ['Universiteit Antwerpen, Antwerpen, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Universiteit Antwerpen, Antwerpen, Belgium',
#       'institution_ids': ['https://openalex.org/I149213910']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107828158',
#      'display_name': 'E. A. De Wolf',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I149213910',
#       'display_name': 'University of Antwerp',
#       'ror': 'https://ror.org/008x57b05',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I149213910']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'E.\u2009A. De Wolf',
#     'raw_affiliation_strings': ['Universiteit Antwerpen, Antwerpen, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Universiteit Antwerpen, Antwerpen, Belgium',
#       'institution_ids': ['https://openalex.org/I149213910']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5050343074',
#      'display_name': 'X. Janssen',
#      'orcid': 'https://orcid.org/0000-0002-3998-4081'},
#     'institutions': [{'id': 'https://openalex.org/I149213910',
#       'display_name': 'University of Antwerp',
#       'ror': 'https://ror.org/008x57b05',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I149213910']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'X. Janssen',
#     'raw_affiliation_strings': ['Universiteit Antwerpen, Antwerpen, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Universiteit Antwerpen, Antwerpen, Belgium',
#       'institution_ids': ['https://openalex.org/I149213910']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5108118585',
#      'display_name': 'J. Lauwers',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I149213910',
#       'display_name': 'University of Antwerp',
#       'ror': 'https://ror.org/008x57b05',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I149213910']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'J. Lauwers',
#     'raw_affiliation_strings': ['Universiteit Antwerpen, Antwerpen, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Universiteit Antwerpen, Antwerpen, Belgium',
#       'institution_ids': ['https://openalex.org/I149213910']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107898443',
#      'display_name': 'M. Van De Klundert',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I149213910',
#       'display_name': 'University of Antwerp',
#       'ror': 'https://ror.org/008x57b05',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I149213910']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'M. Van De Klundert',
#     'raw_affiliation_strings': ['Universiteit Antwerpen, Antwerpen, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Universiteit Antwerpen, Antwerpen, Belgium',
#       'institution_ids': ['https://openalex.org/I149213910']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107831343',
#      'display_name': 'H. Van Haevermaet',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I149213910',
#       'display_name': 'University of Antwerp',
#       'ror': 'https://ror.org/008x57b05',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I149213910']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'H. Van Haevermaet',
#     'raw_affiliation_strings': ['Universiteit Antwerpen, Antwerpen, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Universiteit Antwerpen, Antwerpen, Belgium',
#       'institution_ids': ['https://openalex.org/I149213910']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5012308313',
#      'display_name': 'P. Van Mechelen',
#      'orcid': 'https://orcid.org/0000-0002-8731-9051'},
#     'institutions': [{'id': 'https://openalex.org/I149213910',
#       'display_name': 'University of Antwerp',
#       'ror': 'https://ror.org/008x57b05',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I149213910']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'P. Van Mechelen',
#     'raw_affiliation_strings': ['Universiteit Antwerpen, Antwerpen, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Universiteit Antwerpen, Antwerpen, Belgium',
#       'institution_ids': ['https://openalex.org/I149213910']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5025211898',
#      'display_name': 'N. Van Remortel',
#      'orcid': 'https://orcid.org/0000-0003-4180-8199'},
#     'institutions': [{'id': 'https://openalex.org/I149213910',
#       'display_name': 'University of Antwerp',
#       'ror': 'https://ror.org/008x57b05',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I149213910']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'N. Van Remortel',
#     'raw_affiliation_strings': ['Universiteit Antwerpen, Antwerpen, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Universiteit Antwerpen, Antwerpen, Belgium',
#       'institution_ids': ['https://openalex.org/I149213910']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5105689558',
#      'display_name': 'A. Van Spilbeeck',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I149213910',
#       'display_name': 'University of Antwerp',
#       'ror': 'https://ror.org/008x57b05',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I149213910']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'A. Van Spilbeeck',
#     'raw_affiliation_strings': ['Universiteit Antwerpen, Antwerpen, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Universiteit Antwerpen, Antwerpen, Belgium',
#       'institution_ids': ['https://openalex.org/I149213910']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107911137',
#      'display_name': 'S. Abu Zeid',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'S. Abu Zeid',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5025384198',
#      'display_name': 'F. Blekman',
#      'orcid': 'https://orcid.org/0000-0002-7366-7098'},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'F. Blekman',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5074481660',
#      'display_name': 'J. D’Hondt',
#      'orcid': 'https://orcid.org/0000-0002-9598-6241'},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'J. D’Hondt',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107869505',
#      'display_name': 'N. Daci',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'N. Daci',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5105669594',
#      'display_name': 'I. De Bruyn',
#      'orcid': 'https://orcid.org/0000-0003-1704-4360'},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'I. De Bruyn',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107900817',
#      'display_name': 'K. Deroover',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'K. Deroover',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5049216790',
#      'display_name': 'N. Heracleous',
#      'orcid': 'https://orcid.org/0000-0002-2744-7238'},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'N. Heracleous',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5059553787',
#      'display_name': 'S. Lowette',
#      'orcid': 'https://orcid.org/0000-0003-3984-9987'},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'S. Lowette',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5013651228',
#      'display_name': 'S. Moortgat',
#      'orcid': 'https://orcid.org/0000-0002-6612-3420'},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'S. Moortgat',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107413795',
#      'display_name': 'L. Moreels',
#      'orcid': 'https://orcid.org/0000-0001-8216-4655'},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'L. Moreels',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5113774568',
#      'display_name': 'A. Olbrechts',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'A. Olbrechts',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5072034093',
#      'display_name': 'Q. Python',
#      'orcid': 'https://orcid.org/0000-0001-9397-1057'},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'Q. Python',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5090311900',
#      'display_name': 'S. Tavernier',
#      'orcid': 'https://orcid.org/0000-0002-6792-9522'},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'S. Tavernier',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5109921658',
#      'display_name': 'W. Van Doninck',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I13469542',
#       'display_name': 'Vrije Universiteit Brussel',
#       'ror': 'https://ror.org/006e5kg04',
#       'country_code': 'BE',
#       'type': 'funder',
#       'lineage': ['https://openalex.org/I13469542']}],
#     'countries': ['BE'],
#     'is_corresponding': False,
#     'raw_author_name': 'W. Van Doninck',
#     'raw_affiliation_strings': ['Vrije Universiteit Brussel, Brussel, Belgium'],
#     'affiliations': [{'raw_affiliation_string': 'Vrije Universiteit Brussel, Brussel, Belgium',
#       'institution_ids': ['https://openalex.org/I13469542']}]},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A5107926353',
# ...
#     'is_in_doaj': False,
#     'is_indexed_in_scopus': True,
#     'is_core': True,
#     'host_organization': 'https://openalex.org/P4310320261',
#     'host_organization_name': 'American Physical Society',
#     'host_organization_lineage': ['https://openalex.org/P4310320261'],
#     'host_organization_lineage_names': ['American Physical Society'],
#     'type': 'journal'},
#    'license': 'cc-by',
#    'license_id': 'https://openalex.org/licenses/cc-by',
#    'version': 'publishedVersion',
#    'is_accepted': True,
#    'is_published': True},
#   'sustainable_development_goals': [{'id': 'https://metadata.un.org/sdg/7',
#     'display_name': 'Affordable and clean energy',
#     'score': 0.7}],
#   'grants': [{'funder': 'https://openalex.org/F4320306076',
#     'funder_display_name': 'National Science Foundation',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320306084',
#     'funder_display_name': 'U.S. Department of Energy',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320306151',
#     'funder_display_name': 'Alfred P. Sloan Foundation',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320306196',
#     'funder_display_name': 'Welch Foundation',
#     'award_id': 'C-1845'},
#    {'funder': 'https://openalex.org/F4320308269',
#     'funder_display_name': 'Alexander von Humboldt-Stiftung',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320309746',
#     'funder_display_name': 'Compagnia di San Paolo',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320312062',
#     'funder_display_name': 'Türkiye Atom Enerjisi Kurumu',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320313864',
#     'funder_display_name': 'Thailand Center of Excellence in Physics',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320320768',
#     'funder_display_name': 'Department of Atomic Energy, Government of India',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320320847',
#     'funder_display_name': 'Science Foundation Ireland',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320320879',
#     'funder_display_name': 'Deutsche Forschungsgemeinschaft',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320320924',
#     'funder_display_name': 'Schweizerischer Nationalfonds zur Förderung der Wissenschaftlichen Forschung',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320320997',
#     'funder_display_name': 'Fundação de Amparo à Pesquisa do Estado de São Paulo',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321001',
#     'funder_display_name': 'National Natural Science Foundation of China',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321002',
#     'funder_display_name': 'Research Promotion Foundation',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321079',
#     'funder_display_name': 'Russian Foundation for Basic Research',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321091',
#     'funder_display_name': 'Coordenação de Aperfeiçoamento de Pessoal de Nível Superior',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321108',
#     'funder_display_name': 'Academy of Finland',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321114',
#     'funder_display_name': 'Bundesministerium für Bildung und Forschung',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321133',
#     'funder_display_name': 'Chinese Academy of Sciences',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321181',
#     'funder_display_name': 'Austrian Science Fund',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321540',
#     'funder_display_name': "Ministry of Science and Technology of the People's Republic of China",
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321557',
#     'funder_display_name': 'Chulalongkorn University',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321652',
#     'funder_display_name': 'Eidgenössische Technische Hochschule Zürich',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321730',
#     'funder_display_name': 'Fonds Wetenschappelijk Onderzoek',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321732',
#     'funder_display_name': 'Agentschap voor Innovatie door Wetenschap en Technologie',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321739',
#     'funder_display_name': 'Consejo Nacional de Ciencia y Tecnología',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321838',
#     'funder_display_name': 'Secretaría de Estado de Investigacion, Desarrollo e Innovacion',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321842',
#     'funder_display_name': 'Ministry of Education, Youth and Science',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321873',
#     'funder_display_name': 'Ministero dell’Istruzione, dell’Università e della Ricerca',
#     'award_id': '20108T4XTM'},
#    {'funder': 'https://openalex.org/F4320321896',
#     'funder_display_name': 'Bundesministerium für Wissenschaft, Forschung und Wirtschaft',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321912',
#     'funder_display_name': 'Ministry of Education and Science of the Russian Federation',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321917',
#     'funder_display_name': 'General Secretariat for Research and Technology',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320321983',
#     'funder_display_name': 'Ministry of Business, Innovation and Employment',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322025',
#     'funder_display_name': 'Conselho Nacional de Desenvolvimento Científico e Tecnológico',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322030',
#     'funder_display_name': 'Ministry of Science, ICT and Future Planning',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322120',
#     'funder_display_name': 'National Research Foundation of Korea',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322189',
#     'funder_display_name': 'Joint Institute for Nuclear Research',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322349',
#     'funder_display_name': 'Ministry of Education, Science and Technology',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322381',
#     'funder_display_name': 'A.G. Leventis Foundation',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322437',
#     'funder_display_name': 'National Science and Technology Development Agency',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322463',
#     'funder_display_name': 'Paul Scherrer Institut',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322511',
#     'funder_display_name': 'Narodowe Centrum Nauki',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322604',
#     'funder_display_name': 'Universiti Malaya',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322626',
#     'funder_display_name': 'Türkiye Bilimsel ve Teknolojik Araştırma Kurumu',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322674',
#     'funder_display_name': 'Hrvatska Zaklada za Znanost',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322729',
#     'funder_display_name': 'Ministarstvo Prosvete, Nauke i Tehnološkog Razvoja',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322733',
#     'funder_display_name': 'Ministerstwo Edukacji i Nauki',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322749',
#     'funder_display_name': 'Fundação Carlos Chagas Filho de Amparo à Pesquisa do Estado do Rio de Janeiro',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322795',
#     'funder_display_name': 'Ministry of Science and Technology, Taiwan',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322850',
#     'funder_display_name': 'National Academy of Sciences of Ukraine',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320322892',
#     'funder_display_name': 'Centre National de la Recherche Scientifique',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320323233',
#     'funder_display_name': 'Universidad Autónoma de San Luis Potosí',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320323573',
#     'funder_display_name': 'Ministry of Education and Science',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320323670',
#     'funder_display_name': 'Department of Science and Technology, Government of Kerala',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320323911',
#     'funder_display_name': "Commissariat à l'Énergie Atomique et aux Énergies Alternatives",
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320325176',
#     'funder_display_name': 'Lietuvos Mokslų Akademija',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320325307',
#     'funder_display_name': 'Pakistan Atomic Energy Commission',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320327820',
#     'funder_display_name': 'Federal Agency of Atomic Energy of the Russian Federation',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320332753',
#     'funder_display_name': 'Qatar National Research Fund',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320334632',
#     'funder_display_name': 'Science and Technology Facilities Council',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320334678',
#     'funder_display_name': 'European Research Council',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320334779',
#     'funder_display_name': 'Fundação para a Ciência e a Tecnologia',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320334801',
#     'funder_display_name': 'Russian Academy of Sciences',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320334840',
#     'funder_display_name': 'Fonds pour la Formation à la Recherche dans l’Industrie et dans l’Agriculture',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320334899',
#     'funder_display_name': 'Instituto Nazionale di Fisica Nucleare',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320335322',
#     'funder_display_name': 'European Regional Development Fund',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320335331',
#     'funder_display_name': 'Centro de Investigación y de Estudios Avanzados del Instituto Politécnico Nacional',
#     'award_id': None},
#    {'funder': 'https://openalex.org/F4320338080',
#     'funder_display_name': 'European Social Fund',
#     'award_id': None}],
#   'datasets': [],
#   'versions': ['https://openalex.org/W2519174018'],
#   'referenced_works_count': 50,
#   'referenced_works': ['https://openalex.org/W1602847146',
#    'https://openalex.org/W1837210638',
#    'https://openalex.org/W1864657506',
#    'https://openalex.org/W1873254882',
#    'https://openalex.org/W1893051135',
#    'https://openalex.org/W1964736841',
#    'https://openalex.org/W1972373200',
#    'https://openalex.org/W1985410906',
#    'https://openalex.org/W1991302676',
#    'https://openalex.org/W2029033078',
#    'https://openalex.org/W2037246595',
#    'https://openalex.org/W2047927403',
#    'https://openalex.org/W2058615556',
#    'https://openalex.org/W2062437705',
#    'https://openalex.org/W2082138120',
#    'https://openalex.org/W2095711946',
#    'https://openalex.org/W2099899058',
#    'https://openalex.org/W2100507804',
#    'https://openalex.org/W2107481559',
#    'https://openalex.org/W2118314285',
#    'https://openalex.org/W2121487212',
#    'https://openalex.org/W2128158076',
#    'https://openalex.org/W2130984599',
#    'https://openalex.org/W2133745005',
#    'https://openalex.org/W2144690984',
#    'https://openalex.org/W2146838500',
#    'https://openalex.org/W2150859546',
#    'https://openalex.org/W2151512268',
#    'https://openalex.org/W2153338222',
#    'https://openalex.org/W2155113454',
#    'https://openalex.org/W2156038923',
#    'https://openalex.org/W2156247879',
#    'https://openalex.org/W2156379501',
#    'https://openalex.org/W2163097950',
#    'https://openalex.org/W2164750300',
#    'https://openalex.org/W2169733482',
#    'https://openalex.org/W2184278756',
#    'https://openalex.org/W2210996367',
#    'https://openalex.org/W2233645533',
#    'https://openalex.org/W2258584306',
#    'https://openalex.org/W2277531286',
#    'https://openalex.org/W2399239850',
#    'https://openalex.org/W2795841556',
#    'https://openalex.org/W3098846361',
#    'https://openalex.org/W3100368338',
#    'https://openalex.org/W3102863431',
#    'https://openalex.org/W3102931941',
#    'https://openalex.org/W3105782036',
#    'https://openalex.org/W3121614399',
#    'https://openalex.org/W941912815'],
#   'related_works': ['https://openalex.org/W3124293921',
#    'https://openalex.org/W3124210402',
#    'https://openalex.org/W2996411940',
#    'https://openalex.org/W2411970763',
#    'https://openalex.org/W2141113952',
#    'https://openalex.org/W2072713978',
#    'https://openalex.org/W1993926965',
#    'https://openalex.org/W1822241872',
#    'https://openalex.org/W1519228572',
#    'https://openalex.org/W1508523757'],
#   'abstract_inverted_index': {'Measurements': [0],
#    'are': [1, 43, 93, 121],
#    'presented': [2],
#    'of': [3, 10, 15, 40, 50, 62, 72, 112],
#    'the': [4, 8, 30, 34, 63, 73, 91, 113, 117],
#    'cross': [5, 55, 98],
#    'section': [6, 56, 99],
#    'for': [7, 67, 76],
#    'production': [9],
#    'at': [11, 17, 33, 36, 132],
#    'least': [12, 18],
#    'four': [13, 114],
#    'jets,': [14],
#    'which': [16],
#    'two': [19],
#    'originate': [20],
#    'from': [21, 137],
#    '$b$': [22],
#    'quarks,': [23],
#    'in': [24, 85],
#    'proton-proton': [25],
#    'collisions.': [26],
#    'Data': [27],
#    'collected': [28],
#    'with': [29, 135],
#    'CMS': [31],
#    'detector': [32],
#    'LHC': [35],
#    'a': [37, 60],
#    'center-of-mass': [38],
#    'energy': [39],
#    '7': [41],
#    'TeV': [42],
#    'used,': [44],
#    'corresponding': [45],
#    'to': [46, 102],
#    'an': [47],
#    'integrated': [48],
#    'luminosity': [49],
#    '$3\\text{': [51],
#    '}\\text{': [52, 69, 105],
#    '}{\\mathrm{pb}}^{\\ensuremath{-}1}$.': [53],
#    'The': [54, 83, 96, 107],
#    'is': [57, 100],
#    'measured': [58, 101],
#    'as': [59],
#    'function': [61],
#    'jet': [64, 74],
#    'transverse': [65],
#    'momentum': [66],
#    '${p}_{\\mathrm{T}}>20\\text{': [68],
#    '}\\mathrm{GeV}$,': [70],
#    'and': [71, 88, 109, 116, 140],
#    'pseudorapidity': [75],
#    '$|\\ensuremath{\\eta}|<2.4$': [77],
#    '($b$': [78],
#    'jets),': [79],
#    '4.7': [80],
#    '(untagged': [81],
#    'jets).': [82],
#    'correlations': [84, 118],
#    'azimuthal': [86],
#    'angle': [87],
#    '${p}_{\\mathrm{T}}$': [89, 110],
#    'between': [90, 119],
#    'jets': [92, 115],
#    'also': [94],
#    'studied.': [95],
#    'inclusive': [97],
#    'be': [103],
#    '$\\ensuremath{\\sigma}(pp\\ensuremath{\\rightarrow}2b+2j+X)=69\\ifmmode\\pm\\else\\textpm\\fi{}3(\\mathrm{stat})\\ifmmode\\pm\\else\\textpm\\fi{}24(\\mathrm{syst})\\text{': [104],
#    '}\\mathrm{nb}$.': [106],
#    '$\\ensuremath{\\eta}$': [108],
#    'distributions': [111],
#    'them': [120],
#    'well': [122],
#    'reproduced': [123],
#    'by': [124],
#    'event': [125],
#    'generators': [126],
#    'that': [127],
#    'combine': [128],
#    'perturbative': [129],
#    'QCD': [130],
#    'calculations': [131],
#    'next-to-leading-order': [133],
#    'accuracy': [134],
#    'contributions': [136],
#    'parton': [138],
#    'showers': [139],
#    'multiparton': [141],
#    'interactions.': [142]},
#   'abstract_inverted_index_v3': None,
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2519174018',
#   'counts_by_year': [{'year': 2025, 'cited_by_count': 1},
#    {'year': 2022, 'cited_by_count': 2},
#    {'year': 2021, 'cited_by_count': 1},
#    {'year': 2020, 'cited_by_count': 3},
#    {'year': 2019, 'cited_by_count': 1},
#    {'year': 2018, 'cited_by_count': 2},
#    {'year': 2017, 'cited_by_count': 1}],
#   'updated_date': '2025-08-23T11:59:48.858649',
#   'created_date': '2016-09-23'}]
