# %%
import pandas as pd
import numpy as np

# %%
prof = pd.read_csv(r"C:\Users\Parsa\Downloads\full_prof_v4.csv")

# %%
prof.shape
# Out:
# (50659, 14)

# %%
prof[49399< prof.id]
# Out:
#           id                                               name  \
# 49400  49400  Hoseyn Sayyaadi (ORCID: 0000-0003-1368-1426; S...
# 49401  49401                                        Reza Kazemi
# 49402  49402                               Ali Asghar Alesheikh
# 49403  49403                             Masoud Aliakbar Golkar
# 49404  49404                                    Dr. M. Shariyat
# ...      ...                                                ...
# 50654  50968                                Leila Emami-Meybodi
# 50655  50969                           Seyed Mohammad kalantari
# 50656  50970                                     Mansour Momeni
# 50657  50971                     Yasaman Hosseinzadeh Dehaghani
# 50658  50972                                         Omid Zandi
#
#                                       university       user_id  \
# 49400       K. N. Toosi University of Technology  wfWq2IsAAAAJ
# 49401       K. N. Toosi University of Technology  cPbr9GEAAAAJ
# ...

# %%
prof.duplicated('name').count()
# Out:
# 50659

# %%
duplicate_counts = prof['name'].value_counts() - 1

# %%
duplicates = duplicate_counts[duplicate_counts > 0]

# %%
duplicates
# Out:
# name
# Hossein Mohammadi        9
# Mohammad Salehi          8
# Ali Ahmadi               7
# Mohammad Sharifi         7
# Mohammad Mohammadi       7
#                         ..
# Rouholah Zare Dorabei    1
# Mohammad Tahmasebi       1
# Alireza Shahidi          1
# Farshid Nasiri           1
# Sara Asadi               1
# Name: count, Length: 1877, dtype: int64

# %%
prof[prof.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, university, user_id, affiliation, v_email_at, interests, cited_by_all, cited_by_since_2020, h_index_all, h_index_since_2020, i10_index_all, i10_index_since_2020, yearly_data]
# Index: []

# %%
df = pd.read_csv(r"C:\Users\Parsa\Downloads\final_dataset\final_articles.csv")

# %%
df.shape
# Out:
# (201405, 18)

# %%
df.head()
# Out:
#     id                                              title  \
# 0   70  Timing of surgery following SARS‐CoV‐2 infecti...
# 1  284  SARS-CoV-2 infection and venous thromboembolis...
# 2  319  Effects of pre‐operative isolation on postoper...
# 3  383  A new label-free immunosensor for detection of...
# 4  395  Parameter identification of complex network dy...
#
#                                              authors publication_date  \
# 0                            COVIDSurg Collaborative           2021/6
# 1  Collaborative COVIDSurg, Collaborative GlobalSurg             2022
# 2  COVIDSurg Collaborative, GlobalSurg Collaborat...          2021/11
# 3  Parviz Norouzi, Mohammad Nezamoddini, Mohammad...        2023/2/19
# 4  Arian Bakhtiarnia, Ali Fahim, Ehsan Maani Mian...           2021/6
#
#                                              journal  volume issue      pages  \
# 0                                        Anaesthesia    76.0     6    748-758
# ...

# %%
df.head().to_csv(r"C:\Users\Parsa\Downloads\sample_articles.csv")
